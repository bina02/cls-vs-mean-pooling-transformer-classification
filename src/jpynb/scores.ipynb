# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/github/cls-vs-mean-pooling-transformer-classification/src/py')

# %% [markdown]
# # Models

# %%
from model import TransformerClassifier

base_model = TransformerClassifier()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-897241635.py in <cell line: 0>()
#       1 from model import TransformerClassifier
#       2
# ----> 3 base_model = TransformerClassifier()
#
# TypeError: TransformerClassifier.__init__() missing 8 required positional arguments: 'vocab_size', 'max_len', 'd_model', 'n_head', 'd_ff', 'n_layers', 'num_class', and 'dropout'
